# %% [markdown]
# # DS-SF-30 | Unit Project 2: Exploratory Data Analysis

# %% [markdown]
# In this project, you will implement the exploratory analysis plan developed in Unit Project 1.  This will lay the groundwork for our our first modeling exercise in Unit Project 3.

# %% [markdown]
# First, load the python libraries you will need for this project:

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', 10)
pd.set_option('display.notebook_repr_html', True)

# %matplotlib inline
plt.style.use('ggplot')

# %% [markdown]
# Then, read in your dataset:

# %%
df = pd.read_csv(os.path.join('..', '..', 'dataset', 'dataset-ucla-admissions.csv'))

df.head()
# Out:
#    admit    gre   gpa  prestige
# 0      0  380.0  3.61       3.0
# 1      1  660.0  3.67       3.0
# 2      1  800.0  4.00       1.0
# 3      1  640.0  3.19       4.0
# 4      0  520.0  2.93       4.0

# %% [markdown]
# ## Questions

# %% [markdown]
# > ### Question 1.  How many observations are in our dataset?

# %%
# TODO
df.count()

#total 400 observations. GRE/GPA include 2 null, Prestige include 1 null.
# Out:
# admit       400
# gre         398
# gpa         398
# prestige    399
# dtype: int64

# %% [markdown]
# Answer:

# %% [markdown]
# > ### Question 2.  Create a summary table.

# %%
# TODO
df.describe()
# Out:
# //anaconda/lib/python2.7/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#             admit         gre        gpa    prestige
# count  400.000000  398.000000  398.00000  399.000000
# mean     0.317500  588.040201    3.39093    2.486216
# std      0.466087  115.628513    0.38063    0.945333
# min      0.000000  220.000000    2.26000    1.000000
# 25%      0.000000         NaN        NaN         NaN
# 50%      0.000000         NaN        NaN         NaN
# 75%      1.000000         NaN        NaN         NaN
# max      1.000000  800.000000    4.00000    4.000000

# %% [markdown]
# > ### Question 3.  Why would `gre` have a larger variance than `gpa`?

# %%
# TODO
# the scale of GRE score data is larger than GPA data. GRE range min is 220, max is 800. GPA range min is 2.26, max is 4

# %% [markdown]
# Answer:

# %% [markdown]
# > ### Question 4.  Drop data points with missing data.

# %%
# TODO
df=df.dropna()

# %% [markdown]
# > ### Question 5.  Confirm that you dropped the correct data.  How can you tell?

# %%
# TODO
df.describe()
# there are no null values in description table.
# Out:
#             admit         gre         gpa    prestige
# count  397.000000  397.000000  397.000000  397.000000
# mean     0.317380  587.858942    3.392242    2.488665
# std      0.466044  115.717787    0.380208    0.947083
# min      0.000000  220.000000    2.260000    1.000000
# 25%      0.000000  520.000000    3.130000    2.000000
# 50%      0.000000  580.000000    3.400000    2.000000
# 75%      1.000000  660.000000    3.670000    3.000000
# max      1.000000  800.000000    4.000000    4.000000

# %% [markdown]
# Answer:

# %% [markdown]
# > ### Question 6.  Create boxplots for `gre` and `gpa`.

# %%
# TODO
df[['gre']].boxplot(figsize = (8, 8))
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   from ipykernel import kernelapp as app
# {'boxes': [<matplotlib.lines.Line2D at 0x115951810>],
#  'caps': [<matplotlib.lines.Line2D at 0x11c783710>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x11c792a10>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x11c7923d0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x11a0aeb90>,
#   <matplotlib.lines.Line2D at 0x11c7830d0>]}

# %%
# TODO
df[['gpa']].boxplot(figsize = (8, 8))
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   from ipykernel import kernelapp as app
# {'boxes': [<matplotlib.lines.Line2D at 0x11d21c0d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x11d21cf90>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x11d2cc2d0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x11d2c1c50>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x11d16b3d0>,
#   <matplotlib.lines.Line2D at 0x11d21c950>]}

# %% [markdown]
# > ### Question 7.  What do boxplots show?

# %% [markdown]
# Answer:

# %%
#the boxplots show the quartiles, mean, min, and max

# %% [markdown]
# > ### Question 8.  Plot the distribution of each variable.

# %%
# TODO

# %%
# TODO
pd.tools.plotting.scatter_matrix(
    df[ ['admit', 'gre', 'gpa', 'prestige'] ],
    diagonal = 'kde', s = 75, figsize = (12, 12)
)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11dad1550>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e5e7cd0>]], dtype=object)

# %%
# TODO

# %%
# TODO

# %% [markdown]
# > ### Question 9.  If our model had an assumption of a normal distribution for `gre` and `gpa`, would we meet that requirement?  Would their distributions need correction?  If so, why, why not?  How?

# %%
# TODO
sm.qqplot(df.gre, line = 's')

# %%
# TODO
sm.qqplot(df.gpa, line = 's')

# %% [markdown]
# Answer:

# %% [markdown]
# > ### Question 10.  Create a correlation matrix for the dataset

# %%
# TODO
df.corr()
# Out:
#              admit       gre       gpa  prestige
# admit     1.000000  0.181202  0.174116 -0.243563
# gre       0.181202  1.000000  0.382408 -0.124533
# gpa       0.174116  0.382408  1.000000 -0.060976
# prestige -0.243563 -0.124533 -0.060976  1.000000

# %% [markdown]
# > ### Question 11.  What did you find?  Which of our variables are potentially colinear?

# %% [markdown]
# Answer:

# %%
# gpa and gre have similar correlation level to student being admitted

# %% [markdown]
# > ### Question 12.  Write an analysis plan for exploring the association between graduate school admission rates and prestige of undergraduate schools.

# %% [markdown]
# Answer:

# %% [markdown]
# > ### Question 13.  What is your hypothesis?

# %% [markdown]
# Answer:

# %%
#students with higher prestige score will have higher chance of admission compared to student who have same gre/gpa but lower prestige score.
